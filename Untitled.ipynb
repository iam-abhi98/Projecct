# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('car_insurance_premium_dataset.csv')
data.head()
# Out:
#    Driver Age  Driver Experience  Previous Accidents  \
# 0          56                 32                   4
# 1          46                 19                   0
# 2          32                 11                   4
# 3          60                  0                   4
# 4          25                  7                   0
#
#    Annual Mileage (x1000 km)  Car Manufacturing Year  Car Age  \
# 0                         17                    2002       23
# 1                         21                    2025        0
# 2                         15                    2020        5
# 3                         19                    1991       34
# 4                         13                    2005       20
#
#    Insurance Premium ($)
# 0                 488.35
# 1                 486.15
# 2                 497.55
# 3                 498.35
# 4                 495.55

# %%
data.shape
# Out:
# (1000, 7)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Driver Age                 1000 non-null   int64
#  1   Driver Experience          1000 non-null   int64
#  2   Previous Accidents         1000 non-null   int64
#  3   Annual Mileage (x1000 km)  1000 non-null   int64
#  4   Car Manufacturing Year     1000 non-null   int64
#  5   Car Age                    1000 non-null   int64
#  6   Insurance Premium ($)      1000 non-null   float64
# dtypes: float64(1), int64(6)
# memory usage: 54.8 KB

# %%
data.describe()
# Out:
#         Driver Age  Driver Experience  Previous Accidents  \
# count  1000.000000        1000.000000           1000.0000
# mean     41.575000          14.759000              2.5680
# std      13.765677          10.544292              1.6989
# min      18.000000           0.000000              0.0000
# 25%      30.000000           6.000000              1.0000
# 50%      42.000000          13.000000              3.0000
# 75%      53.000000          23.000000              4.0000
# max      65.000000          40.000000              5.0000
#
#        Annual Mileage (x1000 km)  Car Manufacturing Year      Car Age  \
# count                1000.000000             1000.000000  1000.000000
# mean                   17.933000             2007.637000    17.363000
# std                     4.410665               10.363331    10.363331
# min                    11.000000             1990.000000     0.000000
# 25%                    14.000000             1999.000000     8.000000
# 50%                    18.000000             2008.000000    17.000000
# 75%                    22.000000             2017.000000    26.000000
# max                    25.000000             2025.000000    35.000000
#
#        Insurance Premium ($)
# count            1000.000000
# mean              493.742250
# std                 5.909689
# min               477.050000
# 25%               489.487500
# 50%               493.950000
# 75%               498.312500
# max               508.150000

# %%
data.isna().sum()
# Out:
# Driver Age                   0
# Driver Experience            0
# Previous Accidents           0
# Annual Mileage (x1000 km)    0
# Car Manufacturing Year       0
# Car Age                      0
# Insurance Premium ($)        0
# dtype: int64

# %%
sns.heatmap(data.isna(),cbar=True)
plt.title('Missing value Heatmap')
plt.show()

# %%
du=data.duplicated().sum()
du
# Out:
# np.int64(0)

# %%
numeric_cols = data.select_dtypes(include=["int64", "float64"]).columns.tolist()
numeric_cols
# Out:
# ['Driver Age',
#  'Driver Experience',
#  'Previous Accidents',
#  'Annual Mileage (x1000 km)',
#  'Car Manufacturing Year',
#  'Car Age',
#  'Insurance Premium ($)']

# %%
for col in numeric_cols:
    plt.figure()
    sns.histplot(data[col],kde=True)
    plt.title(f"Histogram: {col}")
    plt.show()

# %%
for col in numeric_cols:
    plt.figure()
    sns.boxplot(X=data[col])
    plt.title(f"Boxplot:{col}")
    plt.show()

# %%
plt.figure(figsize=(8,6))
sns.heatmap(data.corr(),annot=True,cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
data=data.drop('Car Manufacturing Year',axis=1)

# %%
data
# Out:
#      Driver Age  Driver Experience  Previous Accidents  \
# 0            56                 32                   4
# 1            46                 19                   0
# 2            32                 11                   4
# 3            60                  0                   4
# 4            25                  7                   0
# ..          ...                ...                 ...
# 995          23                  5                   3
# 996          43                  8                   3
# 997          21                  3                   5
# 998          36                 18                   1
# 999          37                 19                   2
#
#      Annual Mileage (x1000 km)  Car Age  Insurance Premium ($)
# 0                           17       23                 488.35
# 1                           21        0                 486.15
# 2                           15        5                 497.55
# 3                           19       34                 498.35
# 4                           13       20                 495.55
# ..                         ...      ...                    ...
# 995                         22        5                 500.00
# 996                         17        2                 494.55
# 997                         19       27                 506.05
# 998                         23       14                 491.45
# 999                         12       23                 492.80
#
# [1000 rows x 6 columns]

# %%
numeric_cols = data.select_dtypes(include=["int64", "float64"]).columns.tolist()

sns.pairplot(data[numeric_cols])
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder, StandardScaler

# %%
le=LabelEncoder()
for col in data.columns:
    if data[col].dtype=="object":
        data[col]=le.fit_transform(df[col].astype(str))

# %%
data.head()
# Out:
#    Driver Age  Driver Experience  Previous Accidents  \
# 0          56                 32                   4
# 1          46                 19                   0
# 2          32                 11                   4
# 3          60                  0                   4
# 4          25                  7                   0
#
#    Annual Mileage (x1000 km)  Car Age  Insurance Premium ($)
# 0                         17       23                 488.35
# 1                         21        0                 486.15
# 2                         15        5                 497.55
# 3                         19       34                 498.35
# 4                         13       20                 495.55

# %%
X=data.drop('Insurance Premium ($)',axis=1)
y=data['Insurance Premium ($)']

# %%
X
# Out:
#      Driver Age  Driver Experience  Previous Accidents  \
# 0            56                 32                   4
# 1            46                 19                   0
# 2            32                 11                   4
# 3            60                  0                   4
# 4            25                  7                   0
# ..          ...                ...                 ...
# 995          23                  5                   3
# 996          43                  8                   3
# 997          21                  3                   5
# 998          36                 18                   1
# 999          37                 19                   2
#
#      Annual Mileage (x1000 km)  Car Age
# 0                           17       23
# 1                           21        0
# 2                           15        5
# 3                           19       34
# 4                           13       20
# ..                         ...      ...
# 995                         22        5
# 996                         17        2
# 997                         19       27
# 998                         23       14
# 999                         12       23
#
# [1000 rows x 5 columns]

# %%
y
# Out:
# 0      488.35
# 1      486.15
# 2      497.55
# 3      498.35
# 4      495.55
#         ...
# 995    500.00
# 996    494.55
# 997    506.05
# 998    491.45
# 999    492.80
# Name: Insurance Premium ($), Length: 1000, dtype: float64

# %%
scaler=StandardScaler()
X_scaled=scaler.fit_transform(X)

# %%
print(X_scaled)
# Out:
# [[ 1.04842048  1.63592078  0.84331996 -0.21163858  0.54420925]
#  [ 0.32161252  0.40240937 -1.51232238  0.69570795 -1.6762649 ]
#  [-0.69591862 -0.35667457  0.84331996 -0.66531184 -1.19355313]
#  ...
#  [-1.49540738 -1.11575851  1.43223054  0.24203469  0.93037867]
#  [-0.40519544  0.30752388 -0.9234118   1.14938122 -0.32467194]
#  [-0.33251464  0.40240937 -0.33450121 -1.34582174  0.54420925]]

# %%
from sklearn.model_selection import train_test_split,GridSearchCV

# %%
X_train,X_test,y_train,y_test=train_test_split(X_scaled,y,test_size=0.2,random_state=42)

# %%
print("\nFinal Shapes:")
print("X_train:", X_train.shape)
print("X_test :", X_test.shape)
print("y_train:", y_train.shape)
print("y_test :", y_test.shape)
# Out:
# Final Shapes:
# X_train: (800, 5)
# X_test : (200, 5)
# y_train: (800,)
# y_test : (200,)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
rf=RandomForestRegressor()

# %%
parameter={
    'n_estimators':[50,100,150,200,250,300],
    'max_depth':[5,10,None],
    'min_samples_split':[2,5]
}

# %%
grid_search=GridSearchCV(rf,param_grid=parameter,cv=5)

# %%
grid_search.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_depth': [5, 10, None],
#                          'min_samples_split': [2, 5],
#                          'n_estimators': [50, 100, 150, 200, 250, 300]})

# %%
grid_search.best_params_
# Out:
# {'max_depth': None, 'min_samples_split': 2, 'n_estimators': 100}

# %%
best_rf=grid_search.best_estimator_

# %%
best_rf
# Out:
# RandomForestRegressor()

# %%
y_pred=best_rf.predict(X_test)

# %%
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# %%
print("\n RANDOM FOREST (GridSearchCV) RESULTS")
print("MAE  :", mae)
print("MSE :", mse)
print("R2   :", r2)
# Out:
#  RANDOM FOREST (GridSearchCV) RESULTS
# MAE  : 0.5571700000000126
# MSE : 0.5741617850000104
# R2   : 0.9830762692073325

# %%
print("\nFirst 5 Predictions:")
print(y_pred[:5])
# Out:
# First 5 Predictions:
# [499.775  495.933  490.1165 501.7345 497.3915]

# %%
single_sample = [[
    35,  # Driver Age
    10,  # Driver Experience
    1,   # Previous Accidents
    15,  # Annual Mileage
    7    # Car Age
]]

# %%
single_sample_scaled = scaler.transform(single_sample)
prediction = best_rf.predict(single_sample_scaled)

print("Predicted Premium =", prediction[0])
# Out:
# C:\Users\HP\miniconda3\envs\ml_env\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Predicted Premium = 492.4309999999997

# %%
from xgboost import XGBRegressor

# %%
xgb=XGBRegressor()

# %%
parameter = {
    "n_estimators": [100, 200, 300],
    "learning_rate": [0.05, 0.1],
    "max_depth": [3, 5, 7],
    "subsample": [0.7, 0.9, 1.0]
}

# %%
grid_search_xgb = GridSearchCV(
    estimator=xgb,
    param_grid=parameter,
    cv=3
)

# %%
grid_search_xgb.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=3,
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None, device=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     feature_types=None, feature_weights=None,
#                                     gamma=None, grow_policy=None,
#                                     importance_type=None,
#                                     interaction_constraints=None...
#                                     max_cat_threshold=None,
#                                     max_cat_to_onehot=None, max_delta_step=None,
#                                     max_depth=None, max_leaves=None,
#                                     min_child_weight=None, missing=nan,
#                                     monotone_constraints=None,
#                                     multi_strategy=None, n_estimators=None,
#                                     n_jobs=None, num_parallel_tree=None, ...),
#              param_grid={'learning_rate': [0.05, 0.1], 'max_depth': [3, 5, 7],
#                          'n_estimators': [100, 200, 300],
#                          'subsample': [0.7, 0.9, 1.0]})

# %%
best_xgb=grid_search_xgb.best_estimator_

# %%
best_xgb
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=3,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=300,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
y_pred_xgb=best_xgb.predict(X_test)

# %%
y_pred_xgb
# Out:
# array([499.32742, 496.8053 , 489.25937, 502.39288, 498.0074 , 495.03568,
#        496.82706, 495.5713 , 495.22137, 501.3134 , 498.67142, 499.32303,
#        504.1916 , 481.98825, 487.50024, 500.25555, 491.33252, 493.50308,
#        503.59485, 497.4744 , 491.6279 , 496.1121 , 492.378  , 494.30194,
#        496.38828, 497.836  , 497.07162, 488.32758, 494.3006 , 497.32968,
#        495.88248, 497.22357, 482.88968, 483.9454 , 493.37173, 493.47833,
#        497.9206 , 502.6129 , 503.07312, 485.73944, 489.16098, 501.9981 ,
#        496.9278 , 492.30908, 484.83517, 493.98825, 491.07663, 477.96768,
#        497.39737, 489.70953, 485.598  , 489.18884, 494.1738 , 494.38208,
#        501.56143, 490.88144, 480.92783, 499.77158, 490.6374 , 494.98264,
#        491.51654, 502.49698, 507.14944, 489.95212, 498.2625 , 503.43005,
#        486.89136, 501.92285, 487.46027, 483.56528, 481.68854, 495.9351 ,
#        490.4275 , 494.60886, 485.28845, 487.9576 , 495.59802, 492.75067,
#        499.49063, 502.33765, 496.16367, 488.7762 , 498.54642, 498.09192,
#        487.51318, 491.57672, 491.4081 , 490.06018, 502.1722 , 498.72012,
#        486.94815, 487.26355, 490.68002, 491.59238, 492.6877 , 489.36597,
#        495.32785, 496.84085, 502.19772, 496.30844, 495.76526, 497.53564,
#        483.5295 , 500.38373, 485.18463, 504.77393, 492.32968, 495.36624,
#        480.26648, 503.0048 , 491.68515, 497.5515 , 496.1192 , 489.65698,
#        494.38394, 498.387  , 484.2287 , 502.63693, 495.85788, 495.95068,
#        496.30707, 489.87097, 488.8301 , 492.87537, 497.47202, 480.8176 ,
#        496.72803, 491.32788, 504.39215, 496.5291 , 497.3877 , 490.19333,
#        499.26285, 500.328  , 498.50897, 483.54797, 495.34   , 495.27203,
#        493.05463, 486.4506 , 494.06036, 499.26196, 490.29343, 500.891  ,
#        493.8001 , 493.5653 , 499.70166, 503.20685, 495.51633, 498.70932,
#        494.81192, 491.34573, 501.33966, 493.43356, 490.76956, 493.3853 ,
#        494.83926, 503.14053, 495.6337 , 486.30762, 500.19797, 497.4741 ,
#        490.657  , 493.2808 , 490.10455, 487.84012, 496.94025, 496.45816,
#        504.12137, 501.40747, 488.4639 , 485.58963, 485.8333 , 499.9826 ,
#        492.147  , 494.63705, 484.81287, 494.71915, 494.4971 , 491.83643,
#        494.0626 , 501.5688 , 492.50424, 497.96796, 499.96054, 499.22827,
#        486.96185, 489.3744 , 494.67526, 488.345  , 484.84204, 495.6791 ,
#        493.36255, 496.00903, 488.6812 , 502.63693, 485.71338, 497.6476 ,
#        489.71088, 496.3081 ], dtype=float32)

# %%
mae = mean_absolute_error(y_test, y_pred_xgb)
mse = mean_squared_error(y_test, y_pred_xgb)
r2 = r2_score(y_test, y_pred_xgb)

# %%
print("\n XGBOOST (GridSearchCV) RESULTS")
print("MAE  :", mae)
print("MSE :", mse)
print("R2   :", r2)
# Out:
#  XGBOOST (GridSearchCV) RESULTS
# MAE  : 0.24957369995117062
# MSE : 0.10151406926158824
# R2   : 0.9970078176138956

# %%
print("\nFirst 5 Predictions:")
print(y_pred_xgb[:5])
# Out:
# First 5 Predictions:
# [499.32742 496.8053  489.25937 502.39288 498.0074 ]

# %%
sample = [[35, 10, 1, 15, 7]]   
sample_scaled = scaler.transform(sample)

pred = best_xgb.predict(sample_scaled)
print("Predicted premium =", pred[0])
# Out:
# Predicted premium = 493.00162
# C:\Users\HP\miniconda3\envs\ml_env\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
